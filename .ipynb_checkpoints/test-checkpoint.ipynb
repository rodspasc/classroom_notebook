# %%
from urllib.request import urlopen
from html.parser import HTMLParser

response = urlopen('https://www.uol.com.br/')
html = response.read()
html = html.decode()
parser = HTMLParser()
parser.feed(html)
# Out:
# '<!DOCTYPE html>\n<html lang="pt" id="facebook" class="no_js">\n<head><meta charset="utf-8" /><meta name="referrer" content="default" id="meta_referrer" /><script nonce="gqsTumj8">function envFlush(a){function b(b){for(var c in a)b[c]=a[c]}window.requireLazy?window.requireLazy(["Env"],b):(window.Env=window.Env||{},b(window.Env))}envFlush({"hostnameRewriterConfig":{"site":"internet.org","inboundName":"web.facebook.com","cdnDomainName":null},"useTrustedTypes":false,"isTrustedTypesReportOnly":false,"ajaxpipe_token":"AXjU7ERF_JWCeDU6e4g","stack_trace_limit":30,"timesliceBufferSize":5000,"show_invariant_decoder":false,"compat_iframe_token":"AQ7vLRYp8sWESgEz5aw","isCQuick":false});</script><script nonce="gqsTumj8">(function(a){function b(b){if(!window.openDatabase)return;b.I_AM_INCOGNITO_AND_I_REALLY_NEED_WEBSQL=function(a,b,c,d){return window.openDatabase(a,b,c,d)};window.openDatabase=function(){throw new Error()}}b(a)})(this);</script><style nonce="gqsTumj8"></style><script nonce="gqsTum
# ...
